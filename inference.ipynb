# %%
from src.models.yolo_model import YoloModel
from PIL import Image

img_1 = Image.open('files/example3.jpg').convert('RGB')
img_2 = Image.open('files/example2.jpg').convert('RGB')
yolo_model = YoloModel(yolo_name='yolov5s')
res_1 = yolo_model(img_1)
res_2 = yolo_model(img_2)
# Out:
# Using cache found in /home/ssaraev/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-11-1 Python-3.8.10 torch-1.11.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 5942MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
res_1
# Out:
# <PIL.Image.Image image mode=RGB size=305x141>

# %%
res_2
# Out:
# <PIL.Image.Image image mode=RGB size=1691x793>

# %%
from src.models.models import VerificationCarsModel
from src.models.cars_model import CarsModel, ArcFace

model_weights = 'weights/tf_efficientnet_b5_drom_v1_4.pth'

car_model = VerificationCarsModel(cars_model_parameters = {}, gpus=[0], emb_size = 512, weights=model_weights)

# %%
car_model(res_1, res_2)
# Out:
# 0.06386459

# %%
emb_1.shape
# Out:
# torch.Size([1, 512])

# %%
import torch
result = res[0]
res[0][torch.argmax(res[0], dim=0)[4]]
# Out:
# tensor([1.89768e+03, 9.64879e+02, 3.58879e+03, 1.75785e+03, 9.26040e-01, 2.00000e+00], device='cuda:0')

# %%
res[0][res[0][:,5] == 2]
# Out:
# tensor([[3.83573e+02, 3.45559e+02, 6.57986e+02, 5.90333e+02, 7.73654e-01, 5.00000e+00],
#         [8.28091e+02, 3.59188e+02, 1.18048e+03, 6.52638e+02, 6.65390e-01, 5.00000e+00]], device='cuda:0')

# %%
res.xyxy
# Out:
# [tensor([[1.22578e+02, 2.18564e+02, 1.61247e+03, 9.60803e+02, 7.42140e-01, 2.00000e+00]], device='cuda:0')]

# %%
res.crop()
# Out:
# Saved 1 image to runs/detect/exp
# Saved results to runs/detect/exp
# [{'box': [tensor(122.57758, device='cuda:0'),
#    tensor(218.56392, device='cuda:0'),
#    tensor(1612.47266, device='cuda:0'),
#    tensor(960.80255, device='cuda:0')],
#   'conf': tensor(0.74214, device='cuda:0'),
#   'cls': tensor(2., device='cuda:0'),
#   'label': 'car 0.74',
#   'im': array([[[ 23,  22,  26],
#           [ 19,  18,  22],
#           [ 23,  22,  26],
#           ...,
#           [ 39,  42,  50],
#           [ 44,  47,  55],
#           [ 42,  45,  53]],
#
#          [[ 27,  26,  30],
#           [ 21,  20,  24],
#           [ 25,  24,  26],
#           ...,
#           [ 47,  50,  58],
#           [ 47,  50,  58],
#           [ 40,  43,  51]],
#
#          [[ 27,  26,  30],
#           [ 23,  22,  26],
#           [ 26,  26,  26],
#           ...,
#           [ 47,  50,  58],
#           [ 48,  51,  59],
#           [ 42,  45,  53]],
#
#          ...,
#
#          [[180, 180, 174],
#           [177, 178, 169],
#           [177, 179, 167],
#           ...,
#           [ 93,  94, 114],
#           [ 92,  93, 113],
#           [ 91,  92, 112]],
#
#          [[167, 164, 166],
#           [165, 163, 163],
#           [175, 174, 164],
#           ...,
#           [ 87,  88, 108],
#           [ 88,  89, 109],
#           [ 90,  91, 111]],
#
#          [[136, 134, 146],
#           [138, 135, 144],
#           [151, 149, 149],
#           ...,
#           [ 92,  91, 111],
#           [ 94,  93, 113],
#           [ 94,  93, 113]]], dtype=uint8)}]
